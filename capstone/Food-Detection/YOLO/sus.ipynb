# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HqlrANePJjGwviySzJCz")
project = rf.workspace("asdf").project("boggle-cubes-8wl9u")
dataset = project.version(1).download("yolov7")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in boggle-cubes-1 to yolov7pytorch: 100% [9380836 / 9380836] bytes
# Extracting Dataset Version Zip to boggle-cubes-1 in yolov7pytorch:: 100%|██████████| 588/588 [00:00<00:00, 5624.89it/s]

# %%
# !python3 train.py --batch 16  --cfg cfg/training/yolov7.yaml --epochs 55 --data boggle-cubes-1/data.yaml --weights 'yolov7.pt' --device 0
# Out:
# YOLOR 🚀 v0.1-84-gb8956dd torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='boggle-cubes-1/data.yaml', device='0', entity=None, epochs=55, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.0, paste_in=0.15
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1    195976  models.yolo.IDetect                     [31, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# /home/ubuntu/yolov7/.env/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 415 layers, 37358376 parameters, 37358376 gradients, 105.6 GFLOPS
#
# Transferred 552/566 items from yolov7.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 95 .bias, 95 conv.weight, 98 other
# train: Scanning 'boggle-cubes-1/train/labels.cache' images and labels... 5425 fo
# val: Scanning 'boggle-cubes-1/test/labels.cache' images and labels... 263 found,
#
# autoanchor: Analyzing anchors... anchors/target = 3.31, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 4 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 55 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/54     10.9G   0.06237    0.1569    0.1941    0.4134        85       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366      0.0265       0.425      0.0343      0.0153
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/54     10.9G   0.03967   0.01418   0.05446    0.1083        67       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.685       0.107      0.0583      0.0335
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/54     10.9G   0.03649   0.01503   0.03909   0.09061        84       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.924      0.0958       0.126      0.0778
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/54     12.3G   0.03331   0.01537   0.03329   0.08197        77       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.691       0.219       0.207       0.127
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/54     12.3G   0.03062   0.01535   0.02979   0.07576       103       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.722       0.241       0.261       0.167
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/54     12.3G   0.02902   0.01525    0.0274   0.07167        94       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.537       0.293       0.226       0.157
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/54     12.3G   0.02823   0.01485   0.02545   0.06854       117       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366        0.64        0.32       0.345       0.228
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/54     12.3G   0.02804   0.01477   0.02418   0.06699        69       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.412       0.417       0.335        0.22
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/54     12.3G   0.02772   0.01437   0.02255   0.06463        78       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.663       0.319       0.377        0.25
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/54     12.3G   0.02694   0.01424    0.0216   0.06279        48       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.614        0.35       0.372       0.242
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/54     12.3G   0.02649   0.01428   0.02105   0.06181        94       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.558       0.432       0.427        0.29
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/54     12.3G   0.02583    0.0144   0.02021   0.06044        58       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.627       0.454       0.452       0.302
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/54     12.3G   0.02591   0.01401   0.01971   0.05962        84       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.563       0.468       0.445       0.298
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/54     12.3G   0.02565   0.01402   0.01914   0.05881        92       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.653       0.475       0.529       0.354
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/54     12.3G    0.0248   0.01404   0.01863   0.05747        58       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.575       0.408       0.471       0.329
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/54     12.3G   0.02482   0.01383   0.01853   0.05719        82       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.622       0.466       0.519       0.365
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/54     12.3G   0.02461   0.01371    0.0179   0.05622        70       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.683       0.445       0.532       0.372
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/54     12.3G   0.02414   0.01352   0.01732   0.05498        71       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366        0.55       0.549       0.529        0.37
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/54     12.3G   0.02424   0.01359   0.01716   0.05499        99       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.621       0.533       0.564       0.386
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/54     12.3G   0.02397   0.01355    0.0172   0.05471        98       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.547       0.569       0.535        0.38
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      20/54     12.3G   0.02364   0.01346   0.01644   0.05355        66       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.682       0.533       0.574       0.415
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      21/54     12.3G   0.02295   0.01329   0.01607   0.05231        65       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.606       0.569       0.555        0.39
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      22/54     12.3G   0.02286   0.01318   0.01558   0.05162       108       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.608       0.603       0.601       0.419
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      23/54     12.3G   0.02265   0.01302   0.01575   0.05142        91       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.576       0.585       0.579       0.414
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      24/54     12.3G   0.02254   0.01297   0.01533   0.05084        49       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.585        0.63       0.607       0.423
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      25/54     12.3G   0.02238   0.01327   0.01505    0.0507        96       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.695       0.519       0.595       0.427
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      26/54     12.3G   0.02183   0.01291   0.01484   0.04958        94       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.648       0.529       0.571       0.406
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      27/54     12.3G   0.02188   0.01282   0.01454   0.04924        45       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.677       0.543       0.571       0.405
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      28/54     12.3G   0.02186   0.01292    0.0146   0.04938        53       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.675       0.568       0.595       0.411
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      29/54     12.3G   0.02112   0.01274   0.01423   0.04808        65       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.715       0.568       0.621       0.427
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      30/54     12.3G   0.02126    0.0127   0.01396   0.04792        87       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.597       0.598       0.609       0.435
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      31/54     12.3G   0.02076   0.01259   0.01371   0.04706       115       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.724       0.547       0.617        0.43
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      32/54     12.3G   0.02067   0.01254   0.01316   0.04637        87       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.686       0.604       0.626        0.44
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      33/54     12.3G    0.0205   0.01236   0.01319   0.04604        78       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.736       0.558       0.622       0.438
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      34/54     12.3G   0.02061   0.01221    0.0126   0.04542        82       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.692       0.588       0.635       0.453
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      35/54     12.3G   0.02019   0.01216   0.01292   0.04527        69       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366        0.53       0.661       0.641       0.465
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      36/54     12.3G   0.02009   0.01198   0.01255   0.04462        80       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.591       0.599       0.617       0.452
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      37/54     12.3G   0.02016    0.0118   0.01218   0.04414        92       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.647       0.582       0.627       0.449
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      38/54     12.3G   0.01949   0.01181    0.0117     0.043       113       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.662       0.583       0.641       0.452
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      39/54     12.3G   0.01911   0.01195   0.01169   0.04275        95       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.632         0.6       0.642       0.466
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      40/54     12.3G   0.01903   0.01177   0.01133   0.04212        92       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.713       0.571       0.637       0.453
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      41/54     12.3G    0.0186   0.01171    0.0115    0.0418        92       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.711       0.598       0.656       0.469
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      42/54     12.3G   0.01892   0.01148   0.01129   0.04169        74       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.644       0.613       0.641       0.458
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      43/54     12.3G   0.01848   0.01162   0.01116   0.04126       108       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.722       0.614       0.661       0.457
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      44/54     12.3G   0.01829   0.01135   0.01055   0.04019        92       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.649       0.635       0.675       0.484
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      45/54     12.3G   0.01836   0.01132   0.01064   0.04031        80       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.685       0.623       0.672       0.468
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      46/54     12.3G    0.0183   0.01114   0.01046   0.03989        68       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.636       0.635       0.672       0.475
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      47/54     12.3G   0.01812   0.01113   0.01016   0.03942        91       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.639       0.659       0.669       0.474
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      48/54     12.3G   0.01815   0.01105   0.01012   0.03932        76       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.763       0.585       0.657       0.472
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      49/54     12.3G    0.0179   0.01103   0.00989   0.03882        74       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.674       0.643       0.675       0.479
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      50/54     12.3G    0.0177   0.01092  0.009959   0.03858        57       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.692       0.634       0.679       0.475
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      51/54     12.3G   0.01757     0.011  0.009947   0.03851        93       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.773       0.599       0.686       0.475
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      52/54     12.3G   0.01756   0.01097  0.009486   0.03801        93       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.631       0.647       0.673       0.484
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      53/54     12.3G   0.01749   0.01094  0.009517   0.03794        74       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.752       0.582       0.663       0.469
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      54/54     12.3G   0.01753   0.01083  0.009501   0.03786        68       640
#                Class      Images      Labels           P           R      mAP@.5
#                  all         263         366       0.691       0.608       0.669       0.474
#                apple         263           4       0.712        0.75       0.683       0.596
#              avocado         263           9       0.651       0.222       0.477       0.294
#               banana         263           3       0.841           1       0.995        0.73
#                bread         263          45       0.737       0.747       0.782       0.612
#             broccoli         263           6       0.653         0.5        0.49       0.318
#               butter         263          18        0.32       0.278       0.236       0.102
#               carrot         263          14       0.483       0.269       0.407       0.253
#               cheese         263           7       0.364       0.169       0.232       0.132
#              chicken         263           5           1           0      0.0446      0.0385
#   chips-french-fries         263           3       0.748           1       0.913       0.648
#               coffee         263          30           1         0.9       0.916       0.736
#             cucumber         263           7       0.428       0.428       0.282       0.237
#       dark-chocolate         263           3       0.971           1       0.995       0.731
#                  egg         263          18       0.609       0.667       0.723       0.563
#         french-beans         263           9       0.877       0.889       0.944       0.565
#          hard-cheese         263           6       0.343       0.667       0.538       0.348
#                  jam         263           7       0.923       0.857       0.937       0.432
#           mayonnaise         263           6           0           0      0.0827      0.0449
#      pasta-spaghetti         263           3       0.548       0.333       0.679       0.537
# pizza-margherita-baked         263           5       0.919           1       0.996       0.888
#     potatoes-steamed         263           8       0.792         0.5       0.671       0.308
#                 rice         263           8        0.82         0.5       0.664       0.548
#                salad         263          48        0.82       0.646       0.773       0.556
#         strawberries         263           4       0.534        0.75       0.888       0.772
#         sweet-pepper         263           4           1        0.37       0.504       0.223
#                  tea         263          10       0.688       0.883       0.845       0.584
#               tomato         263          23       0.435       0.261       0.434       0.225
#         tomato-sauce         263           4       0.901        0.75       0.945       0.761
#                water         263          39       0.892       0.851       0.899       0.609
#             wine-red         263           7       0.823           1       0.961       0.714
#           wine-white         263           3       0.584       0.667        0.79       0.582
# 55 epochs completed in 4.705 hours.
#
# Optimizer stripped from runs/train/exp2/weights/last.pt, 75.1MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, 75.1MB

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --conf 0.1 --source boggle-cubes-1/test/images
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='boggle-cubes-1/test/images', update=False, view_img=False, weights=['runs/train/exp2/weights/best.pt'])
# YOLOR 🚀 v0.1-84-gb8956dd torch 1.11.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/ubuntu/yolov7/.env/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36643592 parameters, 6194944 gradients, 103.7 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#  The image with the result is saved in: runs/detect/exp2/006346_jpg.rf.d53c8277b37075a9537039e73e6a1230.jpg
#  The image with the result is saved in: runs/detect/exp2/006563_jpg.rf.2174a23357dc644cdef47ab4601af852.jpg
#  The image with the result is saved in: runs/detect/exp2/006960_jpg.rf.9ee78ef75c378dd6e109bd5a1e96c2ce.jpg
#  The image with the result is saved in: runs/detect/exp2/007248_jpg.rf.48046303edb376efa33dd321d855c185.jpg
#  The image with the result is saved in: runs/detect/exp2/007433_jpg.rf.6f290a4816946d4d2863e4fbe28a64c4.jpg
#  The image with the result is saved in: runs/detect/exp2/007441_jpg.rf.f06d09b0094da1d3c6064404ac22b43e.jpg
#  The image with the result is saved in: runs/detect/exp2/007673_jpg.rf.0664f8dad2d28769e0e4fc0ed87c8226.jpg
#  The image with the result is saved in: runs/detect/exp2/007783_jpg.rf.143c232a5f2c739c75afae543c2e24f9.jpg
#  The image with the result is saved in: runs/detect/exp2/007946_jpg.rf.2c537be241c0b6d881aae65bca1a29e8.jpg
#  The image with the result is saved in: runs/detect/exp2/008059_jpg.rf.15514791e89150e592b1e28471a4e05d.jpg
#  The image with the result is saved in: runs/detect/exp2/008117_jpg.rf.f7d17d3e89828ba1feab1e8bc4f5e178.jpg
#  The image with the result is saved in: runs/detect/exp2/008197_jpg.rf.d0b88b05ffe72e3421e1a039c2c15b5a.jpg
#  The image with the result is saved in: runs/detect/exp2/008532_jpg.rf.bf4eb0dfede0915d53dfa981471cb0fa.jpg
#  The image with the result is saved in: runs/detect/exp2/008543_jpg.rf.0fdcd83c5cfce5d594bc5339cf571134.jpg
#  The image with the result is saved in: runs/detect/exp2/008569_jpg.rf.d64343f883f74064633fba7103bda5cb.jpg
#  The image with the result is saved in: runs/detect/exp2/009115_jpg.rf.8a9976e203f7afff176277b5f59c6ebb.jpg
#  The image with the result is saved in: runs/detect/exp2/009269_jpg.rf.88420ebb72eb4deeded97187a2cb9428.jpg
#  The image with the result is saved in: runs/detect/exp2/009287_jpg.rf.639c482ba025b5bffea15a15c03896b6.jpg
#  The image with the result is saved in: runs/detect/exp2/009791_jpg.rf.08fe8852692ee6137f693f91c326f12d.jpg
#  The image with the result is saved in: runs/detect/exp2/009963_jpg.rf.848fc15fbfdfa9ad2da7123e3ede3e9b.jpg
#  The image with the result is saved in: runs/detect/exp2/010002_jpg.rf.2408574051a71d8fa18f0726139934bd.jpg
#  The image with the result is saved in: runs/detect/exp2/010044_jpg.rf.67fbf36cdedff8579fbb85d8d5c86a63.jpg
#  The image with the result is saved in: runs/detect/exp2/010175_jpg.rf.20cc8af6f7a2af36dee5c7bc65aa0e4c.jpg
#  The image with the result is saved in: runs/detect/exp2/010198_jpg.rf.fe6d334208a565dfeb2e668b61860a74.jpg
#  The image with the result is saved in: runs/detect/exp2/010421_jpg.rf.9e4ff8c4a559597fe5afbba32d20819d.jpg
#  The image with the result is saved in: runs/detect/exp2/010479_jpg.rf.20bf03573878e68c8cda3eca97d06016.jpg
#  The image with the result is saved in: runs/detect/exp2/010530_jpg.rf.501e8205454daa2679249d30573c8ef4.jpg
#  The image with the result is saved in: runs/detect/exp2/010618_jpg.rf.c73453a77afcc717408f6135ce31184f.jpg
#  The image with the result is saved in: runs/detect/exp2/010738_jpg.rf.e9cd9d5bd0290f98fa879f2fc14b98a8.jpg
#  The image with the result is saved in: runs/detect/exp2/010752_jpg.rf.6cdb2114953abb4077ada9b946a4d131.jpg
#  The image with the result is saved in: runs/detect/exp2/010873_jpg.rf.5fa459bc85b9823e1414291c09053f64.jpg
#  The image with the result is saved in: runs/detect/exp2/011228_jpg.rf.032ee021da22f1cc677464d0647a1a0d.jpg
#  The image with the result is saved in: runs/detect/exp2/011309_jpg.rf.552fe41a86918b3d940a6a53638b1a32.jpg
#  The image with the result is saved in: runs/detect/exp2/011459_jpg.rf.a3d492f93ef42b0ff0f97a1165951a2e.jpg
#  The image with the result is saved in: runs/detect/exp2/011694_jpg.rf.f56be3746f3994e06e10e515a260268f.jpg
#  The image with the result is saved in: runs/detect/exp2/011961_jpg.rf.c6806558c0beed8cd3fc0f4050946c86.jpg
#  The image with the result is saved in: runs/detect/exp2/011980_jpg.rf.8d97ee2ab950c47a019834344b8470e4.jpg
#  The image with the result is saved in: runs/detect/exp2/011999_jpg.rf.dd111b02981a9f8a121c4797c43cad54.jpg
#  The image with the result is saved in: runs/detect/exp2/012276_jpg.rf.89e4e1bb5ce31629b5ea71dfedec07fb.jpg
#  The image with the result is saved in: runs/detect/exp2/012390_jpg.rf.1304d5bf6c33368d2e246ae69897e6bb.jpg
#  The image with the result is saved in: runs/detect/exp2/012583_jpg.rf.e82877167e5a23925393b3b854fba35e.jpg
#  The image with the result is saved in: runs/detect/exp2/012655_jpg.rf.bb98d3d10f6ef31fe48af0836d5d981d.jpg
#  The image with the result is saved in: runs/detect/exp2/012694_jpg.rf.f2189b1d2a8e4d980f37f90fced6a2b0.jpg
#  The image with the result is saved in: runs/detect/exp2/012758_jpg.rf.ceb9f0b6fe31a36d05661b6db9e76115.jpg
#  The image with the result is saved in: runs/detect/exp2/013022_jpg.rf.6bde92d01279d8b4562e5b6816464629.jpg
#  The image with the result is saved in: runs/detect/exp2/013746_jpg.rf.8346d3c9be1720ffeb13a9257de943ff.jpg
#  The image with the result is saved in: runs/detect/exp2/013804_jpg.rf.ff3e3ca8c71c86d2613023442389fda7.jpg
#  The image with the result is saved in: runs/detect/exp2/013824_jpg.rf.b73dcf05b37cdaa4dd60b47d6ed84d82.jpg
#  The image with the result is saved in: runs/detect/exp2/013895_jpg.rf.91b6c87378f6e9735cf352cd933ca858.jpg
#  The image with the result is saved in: runs/detect/exp2/014122_jpg.rf.4e6ce95d399055a4bc258e89676c87e1.jpg
#  The image with the result is saved in: runs/detect/exp2/014933_jpg.rf.788b135d20ad42e1a9b09e649ec5c954.jpg
#  The image with the result is saved in: runs/detect/exp2/014978_jpg.rf.02b405dc2f3057aac628764b7002b30c.jpg
#  The image with the result is saved in: runs/detect/exp2/015110_jpg.rf.024cb6c485d6075ce421ef8d3ed2d566.jpg
#  The image with the result is saved in: runs/detect/exp2/015336_jpg.rf.cdb41c79c62b0cdb565a259136d42680.jpg
#  The image with the result is saved in: runs/detect/exp2/015358_jpg.rf.f1c4edf610c844597cd31b830cefaff2.jpg
#  The image with the result is saved in: runs/detect/exp2/015359_jpg.rf.73062792c473dbe7488753fa6c56a0f3.jpg
#  The image with the result is saved in: runs/detect/exp2/015367_jpg.rf.76d6034000f0687e8bfe01a39b35654c.jpg
#  The image with the result is saved in: runs/detect/exp2/015437_jpg.rf.aca12a2830df3df441f167dd40ec04ab.jpg
#  The image with the result is saved in: runs/detect/exp2/015505_jpg.rf.4e7ad7403e65346109408b1e720e1fc7.jpg
#  The image with the result is saved in: runs/detect/exp2/015593_jpg.rf.144afa7f8984d21e7e2465eec099ad3e.jpg
#  The image with the result is saved in: runs/detect/exp2/015626_jpg.rf.3158fc8713884148cbe8bd61c15bbdde.jpg
#  The image with the result is saved in: runs/detect/exp2/015666_jpg.rf.04387a3c3a90731ee1911c1e2da48471.jpg
#  The image with the result is saved in: runs/detect/exp2/015795_jpg.rf.9dbd9ecbfb2a273a1fca58d6276bb563.jpg
#  The image with the result is saved in: runs/detect/exp2/015899_jpg.rf.b0a2d173d023657fcf6841a2478c8005.jpg
#  The image with the result is saved in: runs/detect/exp2/015928_jpg.rf.5e836e7953dee4e6d72d278919966adc.jpg
#  The image with the result is saved in: runs/detect/exp2/016294_jpg.rf.3599188e39b9a974a782d827e378c4ad.jpg
#  The image with the result is saved in: runs/detect/exp2/016634_jpg.rf.4a53257aa0655dec77e81a43f9d82ef0.jpg
#  The image with the result is saved in: runs/detect/exp2/016677_jpg.rf.9ec5859b6f37d87199f8183ee69991b2.jpg
#  The image with the result is saved in: runs/detect/exp2/016940_jpg.rf.8a533246c6f6ffef715a92124fc6bb2f.jpg
#  The image with the result is saved in: runs/detect/exp2/017010_jpg.rf.0c9b67a59bd748c88e696e54688488f2.jpg
#  The image with the result is saved in: runs/detect/exp2/017084_jpg.rf.843ad9b84138883247c27ec7f8cf3a46.jpg
#  The image with the result is saved in: runs/detect/exp2/017451_jpg.rf.9b2924ae6e0daa81cee76b2804ce9c30.jpg
#  The image with the result is saved in: runs/detect/exp2/017744_jpg.rf.3e3ef550eb484f5657e271266275ed2e.jpg
#  The image with the result is saved in: runs/detect/exp2/017866_jpg.rf.12be7913ef372a4014ff70508d37786d.jpg
#  The image with the result is saved in: runs/detect/exp2/017973_jpg.rf.f414023485c52f877c2ec688e624de69.jpg
#  The image with the result is saved in: runs/detect/exp2/018339_jpg.rf.14a3306dc7e5dd2946b78e2b27d6f8ce.jpg
#  The image with the result is saved in: runs/detect/exp2/018636_jpg.rf.220736e963e47ece76459076dd186d24.jpg
#  The image with the result is saved in: runs/detect/exp2/018923_jpg.rf.d8bd52ef20114faf8c540c96cca8ba74.jpg
#  The image with the result is saved in: runs/detect/exp2/019540_jpg.rf.aae82c72ac16e70965ec7955a3036db9.jpg
#  The image with the result is saved in: runs/detect/exp2/019552_jpg.rf.89bd3761c0e78de926e472701e1a347d.jpg
#  The image with the result is saved in: runs/detect/exp2/019695_jpg.rf.140682e5deb1645b030f5d80351d6c64.jpg
#  The image with the result is saved in: runs/detect/exp2/019806_jpg.rf.ce04a1c62637af384f8d3adeadf1df33.jpg
#  The image with the result is saved in: runs/detect/exp2/019884_jpg.rf.b88c8c4d505d744877c75c118fbb5bf9.jpg
#  The image with the result is saved in: runs/detect/exp2/019924_jpg.rf.4ebf5f59dc16c5c83b5c5647b42b590c.jpg
#  The image with the result is saved in: runs/detect/exp2/020103_jpg.rf.d2eb04cf4e79d561fcd8f78ebaf79c62.jpg
#  The image with the result is saved in: runs/detect/exp2/020671_jpg.rf.ea5dd88e2b3c188c54407478dd8a3e15.jpg
#  The image with the result is saved in: runs/detect/exp2/021173_jpg.rf.937931884fe4b9304364301c6c97904f.jpg
#  The image with the result is saved in: runs/detect/exp2/021339_jpg.rf.f5c92b39f19825a93a841c29605b90b3.jpg
#  The image with the result is saved in: runs/detect/exp2/021801_jpg.rf.d4ce102857033fcf7627dfe16138e20e.jpg
#  The image with the result is saved in: runs/detect/exp2/022200_jpg.rf.869ef3ecc37bbbd4444c9a8db20afd03.jpg
#  The image with the result is saved in: runs/detect/exp2/022647_jpg.rf.265a1e51bbbe8e345584f8031e133168.jpg
#  The image with the result is saved in: runs/detect/exp2/022759_jpg.rf.41ee1d93b9b50761e7b2522e2a2011ca.jpg
#  The image with the result is saved in: runs/detect/exp2/022871_jpg.rf.4d62045707bc403a079f1556a0e725c5.jpg
#  The image with the result is saved in: runs/detect/exp2/023393_jpg.rf.79ae1a7d4504567d277871db7a6d5ee9.jpg
#  The image with the result is saved in: runs/detect/exp2/023404_jpg.rf.603e7998fa92ef062917f255ace5fe5e.jpg
#  The image with the result is saved in: runs/detect/exp2/023869_jpg.rf.a43c468f038b95def69e8b5003c8e90a.jpg
#  The image with the result is saved in: runs/detect/exp2/024309_jpg.rf.2d7d98e65995b36d2062f77136972e62.jpg
#  The image with the result is saved in: runs/detect/exp2/024538_jpg.rf.133d1722824c94ac6f378b2c85dbdbc1.jpg
#  The image with the result is saved in: runs/detect/exp2/024633_jpg.rf.5bdf555de2256970c25d1529da13531e.jpg
#  The image with the result is saved in: runs/detect/exp2/024895_jpg.rf.22caab9cd324da57597adcde69ade1c5.jpg
#  The image with the result is saved in: runs/detect/exp2/025018_jpg.rf.16fc7615886c9c6c295e107510c12d01.jpg
#  The image with the result is saved in: runs/detect/exp2/025134_jpg.rf.ace393c68e1b27554c0f76ffd703ae37.jpg
#  The image with the result is saved in: runs/detect/exp2/025168_jpg.rf.a31e4dd14ec0882dca0d11c79232e172.jpg
#  The image with the result is saved in: runs/detect/exp2/025191_jpg.rf.b1c2a884218a7308e66870a3f7a59708.jpg
#  The image with the result is saved in: runs/detect/exp2/025213_jpg.rf.d154cef4dcd44d0abfaa3eb649917500.jpg
#  The image with the result is saved in: runs/detect/exp2/025370_jpg.rf.2b64d744ee7221a0002674544a5cea3c.jpg
#  The image with the result is saved in: runs/detect/exp2/025668_jpg.rf.dffc77f7dc7c4372172594339eae354e.jpg
#  The image with the result is saved in: runs/detect/exp2/026067_jpg.rf.d4b42e21f5a2c147a7300ce10b72d271.jpg
#  The image with the result is saved in: runs/detect/exp2/026204_jpg.rf.78f5b5c6d52307fca8efae5532eab140.jpg
#  The image with the result is saved in: runs/detect/exp2/026315_jpg.rf.b6240b9bea1a5bd578c7b14ae74f9e82.jpg
#  The image with the result is saved in: runs/detect/exp2/026626_jpg.rf.e6644c6713c2c6708ed0a59b9909f2f7.jpg
#  The image with the result is saved in: runs/detect/exp2/026803_jpg.rf.d6b0a409f533f830049a51501ca8a910.jpg
#  The image with the result is saved in: runs/detect/exp2/027676_jpg.rf.875d500c128153d77905497a629b7296.jpg
#  The image with the result is saved in: runs/detect/exp2/027731_jpg.rf.ca4b39a6675cd5d069160a2abacd3353.jpg
#  The image with the result is saved in: runs/detect/exp2/027734_jpg.rf.6bc95df2d52e9411831ae5a2d74c3e8a.jpg
#  The image with the result is saved in: runs/detect/exp2/028278_jpg.rf.13fbf35639ad47f843b9b48d6bfa358b.jpg
#  The image with the result is saved in: runs/detect/exp2/028306_jpg.rf.2de1038b097e416336349f4bb7e78970.jpg
#  The image with the result is saved in: runs/detect/exp2/028452_jpg.rf.2ac9ef9a036eafbc4e5f80416af8337b.jpg
#  The image with the result is saved in: runs/detect/exp2/028856_jpg.rf.efb2e17b13f2b713a5a89267aefb802a.jpg
#  The image with the result is saved in: runs/detect/exp2/028884_jpg.rf.aabe629ca293d4e05d6128e0fb27013c.jpg
#  The image with the result is saved in: runs/detect/exp2/028946_jpg.rf.7093b57cae05d5f61a333dc80769c17e.jpg
#  The image with the result is saved in: runs/detect/exp2/029384_jpg.rf.c860943a43d8638606cb7d4cbdd16351.jpg
#  The image with the result is saved in: runs/detect/exp2/029455_jpg.rf.edca68d8d6fa97a52abff3955985dc87.jpg
#  The image with the result is saved in: runs/detect/exp2/029494_jpg.rf.8a0349369e3ecdd4653d607340c48e8a.jpg
#  The image with the result is saved in: runs/detect/exp2/030180_jpg.rf.2c67e4de0c40306d1f2f6bb7b6d7c580.jpg
#  The image with the result is saved in: runs/detect/exp2/030293_jpg.rf.ceba15fc3c7223f01de8bd42e24a5a78.jpg
#  The image with the result is saved in: runs/detect/exp2/030531_jpg.rf.87577e95e5260853b269ca5d60d2f3df.jpg
#  The image with the result is saved in: runs/detect/exp2/031100_jpg.rf.28a1066adcd5a762dc0193d47f78fc2a.jpg
#  The image with the result is saved in: runs/detect/exp2/031199_jpg.rf.06ec0e4a3e62a1ee3db00758a7b1841c.jpg
#  The image with the result is saved in: runs/detect/exp2/031304_jpg.rf.29c868551759a8f2c3da8d051e0e189e.jpg
#  The image with the result is saved in: runs/detect/exp2/031320_jpg.rf.83a3a3ad3289f1615896d26faeca9c49.jpg
#  The image with the result is saved in: runs/detect/exp2/031334_jpg.rf.350d33c0f006c5d1465d7af3a82762de.jpg
#  The image with the result is saved in: runs/detect/exp2/031450_jpg.rf.d3f48ea47ef632394bc4b75a3b7eab71.jpg
#  The image with the result is saved in: runs/detect/exp2/031457_jpg.rf.83c1d0d6b6e99edbdd3e8dd279c52129.jpg
#  The image with the result is saved in: runs/detect/exp2/031506_jpg.rf.8fe1bd487c27409d59ec662bb5a525fe.jpg
#  The image with the result is saved in: runs/detect/exp2/031648_jpg.rf.0d1c77db017151f787fe19c17c56b577.jpg
#  The image with the result is saved in: runs/detect/exp2/032045_jpg.rf.f2e7066e0509819f78ee9a2006941183.jpg
#  The image with the result is saved in: runs/detect/exp2/032275_jpg.rf.94b4d7bebfc9c46d8ef7f77716e1914a.jpg
#  The image with the result is saved in: runs/detect/exp2/032538_jpg.rf.fe6e58e98fbcd5e0b392f3904d4fdd0b.jpg
#  The image with the result is saved in: runs/detect/exp2/032690_jpg.rf.6e5987f9e4359cb5902e8f85118b89ff.jpg
#  The image with the result is saved in: runs/detect/exp2/033146_jpg.rf.7b56c8a746a5275c6ca0d790e415308c.jpg
#  The image with the result is saved in: runs/detect/exp2/033214_jpg.rf.a3ccaf95313857398162c9b24a26d0f2.jpg
#  The image with the result is saved in: runs/detect/exp2/033426_jpg.rf.b9931cf28ce0fe0a39e9cd2dbd8660a7.jpg
#  The image with the result is saved in: runs/detect/exp2/033806_jpg.rf.1ecc140943635565430bf13ffe418c97.jpg
#  The image with the result is saved in: runs/detect/exp2/034253_jpg.rf.870648c0158a772890bd49051725a5f1.jpg
#  The image with the result is saved in: runs/detect/exp2/034332_jpg.rf.b1c56f5635770721a126358c5505101d.jpg
#  The image with the result is saved in: runs/detect/exp2/034356_jpg.rf.930af0b6eed45fda2e3f39fbd13d6a44.jpg
#  The image with the result is saved in: runs/detect/exp2/034419_jpg.rf.0c3ec13ed0e9d8f2b64f5030487f8d20.jpg
#  The image with the result is saved in: runs/detect/exp2/034656_jpg.rf.2d050a2ef1bdc35b29b1d2effcb56b59.jpg
#  The image with the result is saved in: runs/detect/exp2/035021_jpg.rf.ee5428f758228b81807d7f3e5d651f4a.jpg
#  The image with the result is saved in: runs/detect/exp2/035308_jpg.rf.bee6c529b0be15c9fe5d0396588f533c.jpg
#  The image with the result is saved in: runs/detect/exp2/035467_jpg.rf.2a697e74eb86b30fd6084808d5e051c8.jpg
#  The image with the result is saved in: runs/detect/exp2/035547_jpg.rf.e88e2d7c67f906565f614ee16b67320d.jpg
#  The image with the result is saved in: runs/detect/exp2/035587_jpg.rf.d7b60e20c83db81d5d4c6bd312069fed.jpg
#  The image with the result is saved in: runs/detect/exp2/035944_jpg.rf.22027ef3da9f9f92cbcbc7051163e30c.jpg
#  The image with the result is saved in: runs/detect/exp2/035952_jpg.rf.b9caa633db55f07edfe1827210ac185c.jpg
#  The image with the result is saved in: runs/detect/exp2/036117_jpg.rf.8e29b6bd383de16b2302dc1c2d53e593.jpg
#  The image with the result is saved in: runs/detect/exp2/036373_jpg.rf.f02fdd2d9fd2cec0508e727800fbe988.jpg
#  The image with the result is saved in: runs/detect/exp2/036445_jpg.rf.48356f1014b7432fcbf67da42eec4267.jpg
#  The image with the result is saved in: runs/detect/exp2/036530_jpg.rf.ac66f8c483995b2c9ab39cd68acd2110.jpg
#  The image with the result is saved in: runs/detect/exp2/036985_jpg.rf.565b1279b9c5a73b7737722242dac7b4.jpg
#  The image with the result is saved in: runs/detect/exp2/037417_jpg.rf.fc0f916a0ef5adbb7f0bee40ea876073.jpg
#  The image with the result is saved in: runs/detect/exp2/037476_jpg.rf.9679e5ad0143979f1e75f23bf852f5e6.jpg
#  The image with the result is saved in: runs/detect/exp2/037589_jpg.rf.bdfc929aa7e2aaa98167feae0876970e.jpg
#  The image with the result is saved in: runs/detect/exp2/037616_jpg.rf.2e7824917ff1393eb10b5ea2a2987448.jpg
#  The image with the result is saved in: runs/detect/exp2/037851_jpg.rf.fd3e4307bc868cd52fd6e78a79ea680d.jpg
#  The image with the result is saved in: runs/detect/exp2/037893_jpg.rf.02f77dee6ef4ed52e794c5964f335fa1.jpg
#  The image with the result is saved in: runs/detect/exp2/037916_jpg.rf.8db99654e663ca035313301b22b4514f.jpg
#  The image with the result is saved in: runs/detect/exp2/038159_jpg.rf.dbac7ee048895bdc6892e6308c930e03.jpg
#  The image with the result is saved in: runs/detect/exp2/038213_jpg.rf.d5b66e47b3e2061e5225893d28ce8ca5.jpg
#  The image with the result is saved in: runs/detect/exp2/038233_jpg.rf.c543f7fdb9ea39926538fb450374281f.jpg
#  The image with the result is saved in: runs/detect/exp2/038272_jpg.rf.4beddb82fd1f566a636031437d694d82.jpg
#  The image with the result is saved in: runs/detect/exp2/038280_jpg.rf.4e8d1e0f7aa5f93a6949eb082b0ff179.jpg
#  The image with the result is saved in: runs/detect/exp2/038373_jpg.rf.5ac68cd98844e4eb863fbf1fdcecc1e5.jpg
#  The image with the result is saved in: runs/detect/exp2/038398_jpg.rf.abe6ed190b5dcf879ac4da983a5ed31b.jpg
#  The image with the result is saved in: runs/detect/exp2/038405_jpg.rf.711e7663af0bb1f0c1724ce564277f16.jpg
#  The image with the result is saved in: runs/detect/exp2/038486_jpg.rf.4575054695579d25e050604ecf8ce0e5.jpg
#  The image with the result is saved in: runs/detect/exp2/038512_jpg.rf.c5fb8d1945ce83e01e8b7c91995693f5.jpg
#  The image with the result is saved in: runs/detect/exp2/038917_jpg.rf.38849b7d6f1b1952a24b79b8a9c168f6.jpg
#  The image with the result is saved in: runs/detect/exp2/038937_jpg.rf.9cc2f70d2570b7afdd0f6548a2c87b00.jpg
#  The image with the result is saved in: runs/detect/exp2/039172_jpg.rf.56c0709d1dc4808c0a62004d2e148358.jpg
#  The image with the result is saved in: runs/detect/exp2/039553_jpg.rf.fc3da17b2038b9a90fd759266f1c62f7.jpg
#  The image with the result is saved in: runs/detect/exp2/039870_jpg.rf.f17ba3229a572f7df2cb72f4a6c8eca6.jpg
#  The image with the result is saved in: runs/detect/exp2/039943_jpg.rf.aad7730592a0eefcc8fe8812735d3345.jpg
#  The image with the result is saved in: runs/detect/exp2/040090_jpg.rf.94b8ac51d84737de4cc1fdc11d2482e2.jpg
#  The image with the result is saved in: runs/detect/exp2/040143_jpg.rf.a99f1b87cf71c907659dfcfae0195452.jpg
#  The image with the result is saved in: runs/detect/exp2/040441_jpg.rf.68f22a43cbbf19f3b3c14670fb01844c.jpg
#  The image with the result is saved in: runs/detect/exp2/040446_jpg.rf.f678ece8ee69f3edea80a0eb8d93f622.jpg
#  The image with the result is saved in: runs/detect/exp2/040448_jpg.rf.4e18b73781cea351944bbc974ea5bda4.jpg
#  The image with the result is saved in: runs/detect/exp2/040477_jpg.rf.9a7549ceadbf563044e587ea7ae12287.jpg
#  The image with the result is saved in: runs/detect/exp2/040571_jpg.rf.af1711edee9d7789f17704e2a02cbe0b.jpg
#  The image with the result is saved in: runs/detect/exp2/040612_jpg.rf.333f98d1e0f2ec1e98b376b8224c3b23.jpg
#  The image with the result is saved in: runs/detect/exp2/040677_jpg.rf.6b043b2d0d00083aa60f3863041cb83a.jpg
#  The image with the result is saved in: runs/detect/exp2/040792_jpg.rf.2eaf022554ec59f7ab2a2848bbc480e9.jpg
#  The image with the result is saved in: runs/detect/exp2/040800_jpg.rf.28edbefe92690f21e64a4453cb22cfea.jpg
#  The image with the result is saved in: runs/detect/exp2/040828_jpg.rf.c4825a7c5b3723b8821e7cf7361ac606.jpg
#  The image with the result is saved in: runs/detect/exp2/040917_jpg.rf.75fe51725556aeb7cfead344f2074a96.jpg
#  The image with the result is saved in: runs/detect/exp2/040931_jpg.rf.08bfa1c54b852d9a09457989f8535c53.jpg
#  The image with the result is saved in: runs/detect/exp2/040965_jpg.rf.9a8add99fec5e1adeea053b06c44c3bb.jpg
#  The image with the result is saved in: runs/detect/exp2/041060_jpg.rf.225549db795ff83a61addbb7aba101c2.jpg
#  The image with the result is saved in: runs/detect/exp2/041165_jpg.rf.7c09761e27e89ea23e2c71f69db82b1c.jpg
#  The image with the result is saved in: runs/detect/exp2/041197_jpg.rf.44e155fe0a9fed6b803b594c63f04d9a.jpg
#  The image with the result is saved in: runs/detect/exp2/041271_jpg.rf.2ef61fe4aa0d757fa8b7906f53c8aae5.jpg
#  The image with the result is saved in: runs/detect/exp2/041299_jpg.rf.847a0f7da026c7f7e986bf4722c57b92.jpg
#  The image with the result is saved in: runs/detect/exp2/041452_jpg.rf.a3810099fdc4427ebee42ad875a74a49.jpg
#  The image with the result is saved in: runs/detect/exp2/041609_jpg.rf.7e08906a62b8c03c71f0ea3d8a2f01e9.jpg
#  The image with the result is saved in: runs/detect/exp2/041690_jpg.rf.8c274345630aca04de0bd04b0121e86f.jpg
#  The image with the result is saved in: runs/detect/exp2/041884_jpg.rf.703b9609a2f5b3c1557bbc6d305c5136.jpg
#  The image with the result is saved in: runs/detect/exp2/042108_jpg.rf.1982dbe94f994108cd508de00871767a.jpg
#  The image with the result is saved in: runs/detect/exp2/042206_jpg.rf.b80958cf9f91671e001f1db8cff62b1d.jpg
#  The image with the result is saved in: runs/detect/exp2/042401_jpg.rf.fb1d9cd3271182c3dbcb9859f671a7d3.jpg
#  The image with the result is saved in: runs/detect/exp2/043016_jpg.rf.558da564b3bf0e7b52e6e2000fb704db.jpg
#  The image with the result is saved in: runs/detect/exp2/043124_jpg.rf.f9ff12e3b5d495fb71c3fd134928bd28.jpg
#  The image with the result is saved in: runs/detect/exp2/043729_jpg.rf.346280c4ab4c96a4e117b80d2764e865.jpg
#  The image with the result is saved in: runs/detect/exp2/044215_jpg.rf.0b7fa023960d16f54221245d42c4e08d.jpg
#  The image with the result is saved in: runs/detect/exp2/044450_jpg.rf.6f63ebc9707964934613bbaf71e5b3df.jpg
#  The image with the result is saved in: runs/detect/exp2/044559_jpg.rf.0d71a77b9da96dd34866d07f79979e6d.jpg
#  The image with the result is saved in: runs/detect/exp2/044627_jpg.rf.453356e97e5d2ee19b746cc62a79244a.jpg
#  The image with the result is saved in: runs/detect/exp2/044722_jpg.rf.10f4ce1e7f1bbe127cf3ad36aaeb1004.jpg
#  The image with the result is saved in: runs/detect/exp2/044883_jpg.rf.5431cccee7220a08100036a8fc68076b.jpg
#  The image with the result is saved in: runs/detect/exp2/044976_jpg.rf.891ccc1dca9e56092db04afaf439f7ac.jpg
#  The image with the result is saved in: runs/detect/exp2/045214_jpg.rf.6858240974ca13b79f7ba37faa98632c.jpg
#  The image with the result is saved in: runs/detect/exp2/045649_jpg.rf.4720d6df0ebe1373231ba8bfb7f7f6e7.jpg
#  The image with the result is saved in: runs/detect/exp2/045992_jpg.rf.b420e697385b51c3d9698387d8c85fa1.jpg
#  The image with the result is saved in: runs/detect/exp2/046405_jpg.rf.f63d819ac2bbe7bb62e3b6539164af2d.jpg
#  The image with the result is saved in: runs/detect/exp2/046430_jpg.rf.4a9592fce8ceffe764270fb92609827a.jpg
#  The image with the result is saved in: runs/detect/exp2/046500_jpg.rf.ba0d8f48e889376212a4fc37ef344f73.jpg
#  The image with the result is saved in: runs/detect/exp2/046790_jpg.rf.23ba0f534369b2e1131a2364ae803db9.jpg
#  The image with the result is saved in: runs/detect/exp2/046793_jpg.rf.5ebc63aa0fea9a5f07f06487f7591b3f.jpg
#  The image with the result is saved in: runs/detect/exp2/047291_jpg.rf.bc1fabd9f1080d5ec8c4ce5b890579b2.jpg
#  The image with the result is saved in: runs/detect/exp2/047511_jpg.rf.a08dc7e171a1b33379cb1698b2117ef2.jpg
#  The image with the result is saved in: runs/detect/exp2/047519_jpg.rf.557e8357db076a03775778b5846f824f.jpg
#  The image with the result is saved in: runs/detect/exp2/048233_jpg.rf.f48179e867ef9ac5dcfbab783ac0b001.jpg
#  The image with the result is saved in: runs/detect/exp2/048270_jpg.rf.6d95ddcd6952200854f14204d2c8dde1.jpg
#  The image with the result is saved in: runs/detect/exp2/048419_jpg.rf.96baa4fa07ad76895ab5e3fe92a96cfc.jpg
#  The image with the result is saved in: runs/detect/exp2/048969_jpg.rf.d219979348654fb93a62b7ed0c353ad5.jpg
#  The image with the result is saved in: runs/detect/exp2/049267_jpg.rf.12da4d6a9bbc4de32e6a3c40a4489c3f.jpg
#  The image with the result is saved in: runs/detect/exp2/049294_jpg.rf.0c4b28304cbe32e6fbfeec23100dd7ed.jpg
#  The image with the result is saved in: runs/detect/exp2/049389_jpg.rf.8f1dfdb759815298de112a7929472616.jpg
#  The image with the result is saved in: runs/detect/exp2/049407_jpg.rf.7bea0e5b8f0c0d90617b37a9c4495363.jpg
#  The image with the result is saved in: runs/detect/exp2/050850_jpg.rf.01b697a0d9f5f4f2a2bc7b152969519c.jpg
#  The image with the result is saved in: runs/detect/exp2/050939_jpg.rf.8f3ca9f36a9daea9c348ab2f79d0168d.jpg
#  The image with the result is saved in: runs/detect/exp2/051624_jpg.rf.447fa85b8e86153edec68a79e8d4894a.jpg
#  The image with the result is saved in: runs/detect/exp2/051707_jpg.rf.7b8ea84af27290dc9dca2dcb492e6075.jpg
#  The image with the result is saved in: runs/detect/exp2/051904_jpg.rf.08cf407fa4682db91c8a41eaa2180786.jpg
#  The image with the result is saved in: runs/detect/exp2/052006_jpg.rf.f59b536340a2a536b354f3035e1e504f.jpg
#  The image with the result is saved in: runs/detect/exp2/052822_jpg.rf.1f750118620ad056b906fa48ef1e7b51.jpg
#  The image with the result is saved in: runs/detect/exp2/053151_jpg.rf.267b71447d6117dfce2a210ab6f31325.jpg
#  The image with the result is saved in: runs/detect/exp2/053183_jpg.rf.cd082eb58832f18204c65b27fa503cfd.jpg
#  The image with the result is saved in: runs/detect/exp2/053230_jpg.rf.9e6f8b51aa5151c13d023fb311e3d8dc.jpg
#  The image with the result is saved in: runs/detect/exp2/053251_jpg.rf.afee29399341b59e632b1b2e2eba5a42.jpg
#  The image with the result is saved in: runs/detect/exp2/053324_jpg.rf.075ba2e268a579dcfb8a0abf06b84ef7.jpg
#  The image with the result is saved in: runs/detect/exp2/053942_jpg.rf.e3a96b32e0c1d4ab30a65445e466e0f6.jpg
#  The image with the result is saved in: runs/detect/exp2/054740_jpg.rf.4771e6f5ae391ab41345fc2ad5ce22d0.jpg
#  The image with the result is saved in: runs/detect/exp2/054951_jpg.rf.67ceed3160b3c3333d6734e43e1f1a8b.jpg
#  The image with the result is saved in: runs/detect/exp2/054978_jpg.rf.a237e64eae343b723e27105c3ac9648b.jpg
#  The image with the result is saved in: runs/detect/exp2/055903_jpg.rf.b9aec08def15d0f8239b59a4ba7f49c6.jpg
#  The image with the result is saved in: runs/detect/exp2/056196_jpg.rf.87b8d80d3f414393cd2a2531f3a59a7a.jpg
#  The image with the result is saved in: runs/detect/exp2/056247_jpg.rf.d3885de3feb960376c57a5ea29f89d2b.jpg
#  The image with the result is saved in: runs/detect/exp2/056504_jpg.rf.15bad048e4fbef883e434bf7252ad3a2.jpg
#  The image with the result is saved in: runs/detect/exp2/056680_jpg.rf.aed998a36fe253aefa175da79409bfdf.jpg
#  The image with the result is saved in: runs/detect/exp2/056742_jpg.rf.0babf349888efb383dde33c7261be772.jpg
#  The image with the result is saved in: runs/detect/exp2/056801_jpg.rf.a1f2154e47dd6625387849c794f12b7c.jpg
# Done. (6.161s)

# %%
import glob
from IPython.display import Image, display
import matplotlib.pyplot as plt
import cv2
i = 0
limit = 100 # max images to print
for imageName in glob.glob('runs/detect/exp2/*.jpg'): #assuming JPG
    if i < limit:
      im = cv2.imread(imageName)
      plt.imshow(im[:,:, ::-1])

    i = i + 1
